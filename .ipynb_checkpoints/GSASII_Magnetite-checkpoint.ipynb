# %% [markdown]
# # Refinement of magnetite phase

# %%
# %matplotlib inline
import G2script as G2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Create the project

# %%
PROJECT_NAME = 'gsas_magnetite.gpx'
gpx = G2.G2Project(newgpx=PROJECT_NAME)
gpx.save()
# Out:
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx

# %% [markdown]
# #### Import the XRPD data as a histogram

# %%
hist = gpx.add_powder_histogram(
    datafile='magnetit.prn', 
    iparams='cuka.instprm',
)
# Out:
# Warning: File /home/edgar1993a/work/pyobjcryst/magnetit.prn has a validation error, continuing
# /home/edgar1993a/work/pyobjcryst/magnetit.prn
# Warning: Bruker brml Reader failed to read /home/edgar1993a/work/pyobjcryst/magnetit.prn
# Warning: File /home/edgar1993a/work/pyobjcryst/magnetit.prn has a validation error, continuing
# Warning: Bruker RAW Reader failed to read /home/edgar1993a/work/pyobjcryst/magnetit.prn
# Warning: File /home/edgar1993a/work/pyobjcryst/magnetit.prn has a validation error, continuing
# Warning: CIF Reader failed to read /home/edgar1993a/work/pyobjcryst/magnetit.prn
# Skipping header line     5.000       166
#
# Skipping header line     5.020       176
#
# Skipping header line     5.040       166
#
# Warning: FullProf .dat Reader failed to read /home/edgar1993a/work/pyobjcryst/magnetit.prn
# Warning: File /home/edgar1993a/work/pyobjcryst/magnetit.prn has a validation error, continuing
# GSAS powder data scan error: no BANK records
# Warning: GSAS powder data Reader failed to read /home/edgar1993a/work/pyobjcryst/magnetit.prn
# /home/edgar1993a/work/pyobjcryst/magnetit.prn read by Reader Topas xye or 2th Fit2D chi
# Instrument parameters read: /home/edgar1993a/work/pyobjcryst/cuka.instprm (G2 fmt) bank None
# 1:3: Trying to find one of END, data_heading
# >     5.000       166
# >     ^
# 1:3: Trying to find one of END, data_heading
# >     5.000       166
# >     ^

# %% [markdown]
# #### Import the magnetite phase from its .cif file

# %%
ph_magnetite = gpx.add_phase(
    phasename='magnetite',
    phasefile="Fe3O4_3.cif",
    histograms=[hist],
)
# Out:
# /home/edgar1993a/work/pyobjcryst/Fe3O4_3.cif read by Reader CIF
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx

# %% [markdown]
# #### Refine background automatically

# %%
hist.calc_autobkg()
hist.set_refinements({"Limits" : {"low"  : 15}, "Background" : {"no. coeffs" : 6, "refine" : True}})
hist.fit_fixed_points()
# Out:
# Using default value of 6.55 for pybaselines.whittaker.[i]arpls background computation
# Number of function calls: 3 Number of observations: 6751 Number of parameters: 6
# fitpeak time =    0.021s,    0.021s/cycle
# Rwp =   21.52%, chi**2 =       126091, reduced chi**2 =  18.69
# Background coefficients for chebyschev-1 function
# value:     21.99382    -2.40084     8.80449    -1.74824     1.50723    -1.74735
# esd  :      0.06421     0.11262     0.10103     0.09914     0.08629     0.08584
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx

# %%
# %matplotlib widget
fig, ax = plt.subplots()
ax.plot(hist.getdata("X"), hist.getdata("yobs"), label="data")
ax.plot(hist.getdata("X"), hist.getdata("ycalc"), label="calculated")
ax.plot(hist.getdata("X"), hist.getdata("background"), label="background")
ax.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### First project refinement to include the peaks of the phase

# %%
gpx.do_refinements()
# Out:
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx
#  Hessian Levenberg-Marquardt SVD refinement on 7 variables:
# initial chi^2 2.3373e+05 with 6751 obs.
# Cycle 0: 0.12s, Chi**2: 1.5058e+05 for 6751 obs., Lambda: 0,  Delta: 0.356, SVD=0
# Cycle 1: 0.12s, Chi**2: 1.5058e+05 for 6751 obs., Lambda: 0,  Delta: 1.14e-09, SVD=0
# converged
# Maximum shift/esd = 0.855 for all cycles
# Read from file:/home/edgar1993a/work/pyobjcryst/gsas_magnetite.bak26.gpx
# Save to file  :/home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx
# GPX file save successful
#  Refinement results are in file: /home/edgar1993a/work/pyobjcryst/gsas_magnetite.lst
#  ***** Refinement successful *****

# %%
# %matplotlib widget
fig, ax = plt.subplots()
ax.plot(hist.getdata("X"), hist.getdata("yobs"), label="data")
ax.plot(hist.getdata("X"), hist.getdata("ycalc"), label="calculated")
ax.plot(hist.getdata("X"), hist.getdata("background"), label="background")
ax.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Refine cell parameters, instrument parameters and crystallite size sequentially

# %%
ref_list = [
    {"set" : {"Cell" : False, "LeBail" : True}},
    {"set" : {"Instrument Parameters" : ["U", "V", "W", "X", "Y", "Z"]}},
    {"set" : {"Sample Parameters" : ["DisplaceX"]}},
    {"set" : {"Scale" : True, "Size" : {"refine" : True}}},
    {"set" : {"HStrain" : True}},
]

gpx.do_refinements(ref_list)
# Out:
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx
#  Hessian Levenberg-Marquardt SVD refinement on 7 variables:
# initial chi^2 1.5058e+05 with 6751 obs.
# divergence: chi^2 1.9964e+05 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e-03
# divergence: chi^2 1.9964e+05 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e-02
# divergence: chi^2 1.9964e+05 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e-01
# divergence: chi^2 1.9964e+05 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e+00
# divergence: chi^2 1.9964e+05 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e+01
# divergence: chi^2 1.9964e+05 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e+02
# ouch #4 stuck: chisq-new 1.996e+05 > chisq0 1.506e+05 with lambda 1e+02
# Maximum shift/esd = 0.000 for all cycles
# Note highly correlated parameters:
#      :0:Back;0 and :0:Back;2 (@71.05%)
# Read from file:/home/edgar1993a/work/pyobjcryst/gsas_magnetite.bak26.gpx
# Save to file  :/home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx
# GPX file save successful
#  Refinement results are in file: /home/edgar1993a/work/pyobjcryst/gsas_magnetite.lst
#  ***** Refinement successful *****
# Reported from refinement:
# Note highly correlated parameters:
#      :0:Back;0 and :0:Back;2 (@71.05%)
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx
#  Hessian Levenberg-Marquardt SVD refinement on 13 variables:
# initial chi^2 2.0066e+05 with 6751 obs.
# Cycle 0: 0.11s, Chi**2: 33856 for 6751 obs., Lambda: 0,  Delta: 0.831, SVD=0
# Cycle 1: 0.15s, Chi**2: 16029 for 6751 obs., Lambda: 0,  Delta: 0.527, SVD=0
# Cycle 2: 0.21s, Chi**2: 12072 for 6751 obs., Lambda: 0,  Delta: 0.247, SVD=0
# Maximum shift/esd = 15.311 for all cycles
# Note highly correlated parameters:
#  ** :0:X and :0:Z (@99.68%)
# Read from file:/home/edgar1993a/work/pyobjcryst/gsas_magnetite.bak26.gpx
# Save to file  :/home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx
# GPX file save successful
#  Refinement results are in file: /home/edgar1993a/work/pyobjcryst/gsas_magnetite.lst
#  ***** Refinement successful *****
# Reported from refinement:
# Note highly correlated parameters:
#  ** :0:X and :0:Z (@99.68%)
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx
#  Hessian Levenberg-Marquardt SVD refinement on 13 variables:
# initial chi^2 10171 with 6751 obs.
# Cycle 0: 0.19s, Chi**2: 9259.1 for 6751 obs., Lambda: 0,  Delta: 0.0897, SVD=0
# divergence: chi^2 9534.8 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e-03
# divergence: chi^2 9531.4 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e-02
# divergence: chi^2 9518.3 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e-01
# divergence: chi^2 9502.7 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e+00
# divergence: chi^2 9498.8 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e+01
# Cycle 1: 0.52s, Chi**2: 9554 for 6751 obs., Lambda: 10,  Delta: -0.0318, SVD=0
# converged
# Maximum shift/esd = 2.659 for all cycles
# Note highly correlated parameters:
#  ** :0:X and :0:Z (@99.75%)
# Read from file:/home/edgar1993a/work/pyobjcryst/gsas_magnetite.bak26.gpx
# Save to file  :/home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx
# GPX file save successful
#  Refinement results are in file: /home/edgar1993a/work/pyobjcryst/gsas_magnetite.lst
#  ***** Refinement successful *****
# Reported from refinement:
# Note highly correlated parameters:
#  ** :0:X and :0:Z (@99.75%)
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx
#  Hessian Levenberg-Marquardt SVD refinement on 15 variables:
# initial chi^2 9580.5 with 6751 obs.
# divergence: chi^2 35188 on 6751 obs. (2 SVD zeros)
# 	increasing Marquardt lambda to 1.0e-03
# divergence: chi^2 11232 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e-02
# Cycle 0: 0.31s, Chi**2: 9008.7 for 6751 obs., Lambda: 0.01,  Delta: 0.0597, SVD=0
# divergence: chi^2 10456 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e-02
# divergence: chi^2 9332 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e-01
# divergence: chi^2 9349.3 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e+00
# divergence: chi^2 9357.9 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e+01
# divergence: chi^2 9378.7 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e+02
# ouch #4 stuck: chisq-new 9379 > chisq0 9009 with lambda 1e+02
# Maximum shift/esd = 1.211 for all cycles
# SVD problem(s) likely from:
#   :0:Y, :0:Z
# Note highly correlated parameters:
#  ** 0:0:Scale and :0:Scale (@100.00%)
#  ** 0:0:Size;i and :0:X (@100.00%)
#  ** 0:0:Size;i and :0:Z (@99.74%)
#  ** :0:X and :0:Z (@99.74%)
# Read from file:/home/edgar1993a/work/pyobjcryst/gsas_magnetite.bak26.gpx
# Save to file  :/home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx
# GPX file save successful
#  Refinement results are in file: /home/edgar1993a/work/pyobjcryst/gsas_magnetite.lst
#  ***** Refinement successful *****
# Reported from refinement:
# Warning: 2 soft (SVD) Hessian singularities
# SVD problem(s) likely from:
# :0:Y, :0:Z
# Note highly correlated parameters:
#  ** 0:0:Scale and :0:Scale (@100.00%)
#  ** 0:0:Size;i and :0:X (@100.00%)
#  ** 0:0:Size;i and :0:Z (@99.74%)
#  ** :0:X and :0:Z (@99.74%)
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx
#  Hessian Levenberg-Marquardt SVD refinement on 17 variables:
# initial chi^2 9416.7 with 6751 obs.
# divergence: chi^2 59235 on 6751 obs. (2 SVD zeros)
# 	increasing Marquardt lambda to 1.0e-03
# divergence: chi^2 9539.4 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e-02
# Cycle 0: 0.32s, Chi**2: 8648.5 for 6751 obs., Lambda: 0.01,  Delta: 0.0816, SVD=0
# divergence: chi^2 9939.3 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e-02
# divergence: chi^2 9016.1 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e-01
# divergence: chi^2 9010.4 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e+00
# divergence: chi^2 8992.5 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e+01
# divergence: chi^2 9014.5 on 6751 obs. (0 SVD zeros)
# 	increasing Marquardt lambda to 1.0e+02
# ouch #4 stuck: chisq-new 9014 > chisq0 8649 with lambda 1e+02
# Maximum shift/esd = 16.202 for all cycles
# SVD problem(s) likely from:
#   :0:Y, :0:Z
# Note highly correlated parameters:
#  ** 0:0:Scale and :0:Scale (@100.00%)
#  ** 0:0:Size;i and :0:X (@100.00%)
#  ** 0:0:Size;i and :0:Z (@99.74%)
#  ** :0:X and :0:Z (@99.74%)
# Read from file:/home/edgar1993a/work/pyobjcryst/gsas_magnetite.bak26.gpx
# Save to file  :/home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx
# GPX file save successful
#  Refinement results are in file: /home/edgar1993a/work/pyobjcryst/gsas_magnetite.lst
#  ***** Refinement successful *****
# Reported from refinement:
# Warning: 2 soft (SVD) Hessian singularities
# SVD problem(s) likely from:
# :0:Y, :0:Z
# Note highly correlated parameters:
#  ** 0:0:Scale and :0:Scale (@100.00%)
#  ** 0:0:Size;i and :0:X (@100.00%)
#  ** 0:0:Size;i and :0:Z (@99.74%)
#  ** :0:X and :0:Z (@99.74%)

# %%
# %matplotlib widget
fig, ax = plt.subplots()
ax.plot(hist.getdata("X"), hist.getdata("yobs"), label="data")
ax.plot(hist.getdata("X"), hist.getdata("ycalc"), label="calculated")
ax.plot(hist.getdata("X"), hist.getdata("background"), label="background")
ax.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Cyclic refinement

# %%
# gpx.set_Controls('sequential',gpx.histograms())
# gpx.set_Controls('cycles',10)

# %% [markdown]
# #### We can refine the powder diffraction data without the CIF file by adding the peaks manually

# %%
PROJECT_NAME = 'gsas_magnetite.gpx'
gpx = G2.G2Project(newgpx=PROJECT_NAME)
gpx.save()
hist = gpx.add_powder_histogram(
    datafile='magnetit.prn', 
    iparams='cuka.instprm',
)
hist.set_refinements({'Limits': [16.,65.],
                      'Background': {"no. coeffs": 6,'type': 'chebyschev-1', 'refine': True},
                      "Instrument Parameters" : ["U", "V", "W", "X", "Y", "Z"],
})
# Out:
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_magnetite.gpx
# Warning: File /home/edgar1993a/work/pyobjcryst/magnetit.prn has a validation error, continuing
# /home/edgar1993a/work/pyobjcryst/magnetit.prn
# Warning: Bruker brml Reader failed to read /home/edgar1993a/work/pyobjcryst/magnetit.prn
# Warning: File /home/edgar1993a/work/pyobjcryst/magnetit.prn has a validation error, continuing
# Warning: Bruker RAW Reader failed to read /home/edgar1993a/work/pyobjcryst/magnetit.prn
# Warning: File /home/edgar1993a/work/pyobjcryst/magnetit.prn has a validation error, continuing
# Warning: CIF Reader failed to read /home/edgar1993a/work/pyobjcryst/magnetit.prn
# Skipping header line     5.000       166
#
# Skipping header line     5.020       176
#
# Skipping header line     5.040       166
#
# Warning: FullProf .dat Reader failed to read /home/edgar1993a/work/pyobjcryst/magnetit.prn
# Warning: File /home/edgar1993a/work/pyobjcryst/magnetit.prn has a validation error, continuing
# GSAS powder data scan error: no BANK records
# Warning: GSAS powder data Reader failed to read /home/edgar1993a/work/pyobjcryst/magnetit.prn
# /home/edgar1993a/work/pyobjcryst/magnetit.prn read by Reader Topas xye or 2th Fit2D chi
# Instrument parameters read: /home/edgar1993a/work/pyobjcryst/cuka.instprm (G2 fmt) bank None
# 1:3: Trying to find one of END, data_heading
# >     5.000       166
# >     ^
# 1:3: Trying to find one of END, data_heading
# >     5.000       166
# >     ^
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 8
#       3 gpx.save()
#       4 hist = gpx.add_powder_histogram(
#       5     datafile='magnetit.prn',
#       6     iparams='cuka.instprm',
#       7 )
# ----> 8 hist.set_refinements({'Limits': [16.,65.],
#       9                       'Background': {"no. coeffs": 6,'type': 'chebyschev-1', 'refine': True},
#      10                       "Instrument parameters" : ["U", "V", "W", "X", "Y", "Z"],
#      11 })
#
# File ~/work/g2home/GSASIIscriptable.py:3452, in G2PwdrData.set_refinements(self, refs)
#    3450                 raise ValueError("Invalid key:", iparam)
#    3451     else:
# -> 3452         raise ValueError("Unknown key:", key)
#    3453 # Fit fixed points after the fact - ensure they are after fixed points
#    3454 # are added
#    3455 if do_fit_fixed_points:
#    3456     # Background won't be fit if refinement flag not set
#
# ValueError: ('Unknown key:', 'Instrument parameters')

# %%
hist.add_peak(area=100, ttheta=18.3)
hist.add_peak(area=1000, ttheta=30.02)
hist.add_peak(area=1000, ttheta=35.48)
hist.add_peak(area=100, ttheta=37.10)
hist.add_peak(area=100, ttheta=43.14)
hist.add_peak(area=100, ttheta=53.59)
hist.add_peak(area=100, ttheta=57.13)
hist.add_peak(area=100, ttheta=62.60)
hist.refine_peaks()
# Out:
# Number of function calls: 3 Number of observations: 2451 Number of parameters: 14
# fitpeak time =    0.057s,    0.057s/cycle
# Rwp =   69.42%, chi**2 =      84841.3, reduced chi**2 =  34.81
# Background coefficients for chebyschev-1 function
# value:     27.04957    -6.07469     7.84574    -1.00383     1.85256    -7.57344
# esd  :      0.80238     1.43050     1.25898     1.18519     0.98247     0.94826
# Peak coefficients:
#                 pos       esd       int       esd       sig       esd       gam       esd        bins
#  Peak1   :  18.30000              1892.4     315.7     4.730               0.000               2.6
#  Peak2   :  30.02000              5144.1     500.7     4.608               0.000               2.5
#  Peak3   :  35.48000             20114.6     972.8     4.565               0.000               2.5
#  Peak4   :  37.10000              1322.5     270.3     4.554               0.000               2.5
#  Peak5   :  43.14000              4049.4     442.3     4.522               0.000               2.5
#  Peak6   :  53.59000              1033.2     237.4     4.500               0.000               2.5
#  Peak7   :  57.13000              3356.0     409.7     4.504               0.000               2.5
#  Peak8   :  62.60000              5245.0     507.0     4.523               0.000               2.5
# *** Warning: data binning yields too few data points across peak FWHM for reliable Rietveld refinement ***
# *** recommended is 6-10; you have 2.50 ***
# ({'Back;0': 0.8023750267529517,
#   'Back;1': 1.4304986208437602,
#   'Back;2': 1.2589826260251282,
#   'Back;3': 1.1851866026173012,
#   'Back;4': 0.9824747006572373,
#   'Back;5': 0.9482585788447505,
#   'int0': 315.74955797441083,
#   'int1': 500.72923341912036,
#   'int2': 972.7983222148398,
#   'int3': 270.34735506804026,
#   'int4': 442.268867151156,
#   'int5': 237.36914100875347,
#   'int6': 409.6735097464877,
#   'int7': 506.998351466172},
#  (array([ 2.70495711e+01, -6.07468509e+00,  7.84573959e+00, -1.00382583e+00,
#           1.85256067e+00, -7.57343794e+00,  1.89240649e+03,  5.14406285e+03,
#           2.01145652e+04,  1.32252156e+03,  4.04939574e+03,  1.03323275e+03,
#           3.35604395e+03,  5.24495573e+03]),
#   array([[ 1.84928171e-02, -5.25306478e-03,  1.97388950e-02,
#           -3.35315639e-03,  9.22500020e-03, -3.75427263e-03,
#           -2.48336959e-01, -5.36024263e-02, -8.59406233e-02,
#           -8.63051987e-02, -5.93506653e-02, -3.55370639e-02,
#           -9.11066378e-02, -2.44457847e-01],
#          [-5.25306478e-03,  5.87791300e-02, -7.15378462e-03,
#            3.19830056e-02, -5.47355227e-03,  1.38204103e-02,
#            4.69283768e-01,  4.21626501e-02,  7.37743362e-02,
#            6.66538867e-02, -8.69396675e-04, -5.26388351e-02,
#           -7.93231739e-02, -4.16442311e-01],
#          [ 1.97388950e-02, -7.15378462e-03,  4.55289611e-02,
#           -7.84570679e-03,  1.97054282e-02, -7.46609570e-04,
#           -4.02830208e-01,  1.46678641e-01,  1.04690023e-01,
#            8.49599720e-02,  5.32923869e-02,  8.37578677e-02,
#            1.31549515e-02, -3.49124073e-01],
#          [-3.35315639e-03,  3.19830056e-02, -7.84570679e-03,
#            4.03479742e-02, -3.94842792e-03,  1.67913875e-02,
#            2.79905141e-01, -1.24183253e-01, -3.38718992e-02,
#           -1.86567743e-02,  5.45119992e-04,  1.51031041e-01,
#            1.80017433e-01, -2.02358291e-01],
#          [ 9.22500020e-03, -5.47355227e-03,  1.97054282e-02,
#           -3.94842792e-03,  2.77262426e-02, -2.98439183e-03,
#           -1.58729186e-01,  6.69019596e-02, -1.09191436e-01,
#           -1.41500139e-01, -1.37605350e-01,  1.66659054e-01,
#            1.84904414e-01, -1.16834187e-01],
#          [-3.75427263e-03,  1.38204103e-02, -7.46609570e-04,
#            1.67913875e-02, -2.98439183e-03,  2.58286572e-02,
#            4.09058903e-02,  1.13623838e-01,  1.93224803e-01,
#            1.62267336e-01, -3.73450659e-02,  2.92150580e-02,
#            1.90871950e-01,  2.03565442e-02],
#          [-2.48336959e-01,  4.69283768e-01, -4.02830208e-01,
#            2.79905141e-01, -1.58729186e-01,  4.09058903e-02,
#            2.86374121e+03, -6.60445118e-01, -4.16483966e-01,
#           -2.46248717e-01,  1.61186037e-01, -1.07424841e-01,
#           -1.59457407e-01,  4.87430531e-02],
#          [-5.36024263e-02,  4.21626501e-02,  1.46678641e-01,
#           -1.24183253e-01,  6.69019596e-02,  1.13623838e-01,
#           -6.60445118e-01,  7.20201731e+03,  3.04279874e+00,
#            2.51352861e+00,  3.09550150e-01, -2.12492662e-01,
#            6.95773953e-01,  3.02306328e-01],
#          [-8.59406233e-02,  7.37743362e-02,  1.04690023e-01,
#           -3.38718992e-02, -1.09191436e-01,  1.93224803e-01,
#           -4.16483966e-01,  3.04279874e+00,  2.71827814e+04,
#            4.03035306e+00,  1.61669836e+00, -7.06762167e-01,
#            1.90611554e-01,  5.07669744e-01],
#          [-8.63051987e-02,  6.66538867e-02,  8.49599720e-02,
#           -1.86567743e-02, -1.41500139e-01,  1.62267336e-01,
#           -2.46248717e-01,  2.51352861e+00,  4.03035306e+00,
#            2.09938706e+03,  1.92917764e+00, -7.11390903e-01,
#           -1.48406894e-01,  4.26370482e-01],
#          [-5.93506653e-02, -8.69396675e-04,  5.32923869e-02,
#            5.45119992e-04, -1.37605350e-01, -3.73450659e-02,
#            1.61186037e-01,  3.09550150e-01,  1.61669836e+00,
#            1.92917764e+00,  5.61850802e+03,  5.78534341e-02,
#           -9.31087290e-01, -2.04054633e-01],
#          [-3.55370639e-02, -5.26388351e-02,  8.37578677e-02,
#            1.51031041e-01,  1.66659054e-01,  2.92150580e-02,
#           -1.07424841e-01, -2.12492662e-01, -7.06762167e-01,
#           -7.11390903e-01,  5.78534341e-02,  1.61844067e+03,
#            3.75007837e+00,  3.82459092e-01],
#          [-9.11066378e-02, -7.93231739e-02,  1.31549515e-02,
#            1.80017433e-01,  1.84904414e-01,  1.90871950e-01,
#           -1.59457407e-01,  6.95773953e-01,  1.90611554e-01,
#           -1.48406894e-01, -9.31087290e-01,  3.75007837e+00,
#            4.82085459e+03,  2.41494965e+00],
#          [-2.44457847e-01, -4.16442311e-01, -3.49124073e-01,
#           -2.02358291e-01, -1.16834187e-01,  2.03565442e-02,
#            4.87430531e-02,  3.02306328e-01,  5.07669744e-01,
#            4.26370482e-01, -2.04054633e-01,  3.82459092e-01,
#            2.41494965e+00,  7.38348440e+03]]),
#   {'fvec': array([ 1.80247182,  1.08298285,  1.38390041, ..., -0.14005753,
#            3.86195799, -1.44307426]),
#    'nfev': 3,
#    'njev': 2,
#    'fjac': array([[-1.04534207e+01,  1.44216593e-02,  1.47610389e-02, ...,
#             1.99470029e-02,  3.02511278e-02,  1.74654968e-02],
#           [-1.89648803e+00,  7.37924782e+00,  2.34880521e-02, ...,
#            -2.24820191e-02, -3.49616903e-02, -2.06884245e-02],
#           [ 6.69551589e-02,  9.22305039e-01, -7.24685950e+00, ...,
#             2.54285073e-02,  3.90402247e-02,  2.28156909e-02],
#           ...,
#           [-1.15097778e-04, -1.60837934e-04,  1.04480578e-05, ...,
#             4.57359411e-04,  7.04130570e-04,  4.12635864e-04],
#           [-1.22128725e-04, -1.32995890e-04,  1.49458215e-05, ...,
#             3.15613031e-03,  4.80163784e-03,  2.78097875e-03],
#           [-3.35068181e-05, -4.91465207e-05, -3.95728860e-05, ...,
#            -1.74689085e-04, -2.69753044e-04, -1.58547725e-04]]),
#    'ipvt': array([ 1,  6,  5,  4,  3,  2, 12, 10,  7, 13, 11,  8, 14,  9],
#          dtype=int32),
#    'qtf': array([-1.35054634e-08,  3.42557958e-08,  3.13839457e-08, -3.53320871e-08,
#            5.29452020e-08, -3.22771156e-08, -1.21098717e-06,  1.01234802e-06,
#            5.98593002e-08, -1.95035941e-08,  1.37651944e-07, -1.07828266e-06,
#           -2.14805956e-06, -6.55118335e-06])},
#   'Both actual and predicted relative reductions in the sum of squares\n  are at most 0.001000',
#   1),
#  array([8.02375027e-01, 1.43049862e+00, 1.25898263e+00, 1.18518660e+00,
#         9.82474701e-01, 9.48258579e-01, 3.15749558e+02, 5.00729233e+02,
#         9.72798322e+02, 2.70347355e+02, 4.42268867e+02, 2.37369141e+02,
#         4.09673510e+02, 5.06998351e+02]),
#  {'Rwp': 69.4187808949416, 'GOF': 34.813824289390965},
#  ['Back;0',
#   'Back;1',
#   'Back;2',
#   'Back;3',
#   'Back;4',
#   'Back;5',
#   'int0',
#   'int1',
#   'int2',
#   'int3',
#   'int4',
#   'int5',
#   'int6',
#   'int7'],
#  {'Back;0': 27.049571052954548,
#   'Back;1': -6.074685090092302,
#   'Back;2': 7.845739585193589,
#   'Back;3': -1.0038258261868902,
#   'Back;4': 1.8525606660308829,
#   'Back;5': -7.573437937923887,
#   'nDebye': 0,
#   'nPeaks': 0,
#   'Back File': '',
#   'BF mult': 1.0,
#   'Type': 'PXC',
#   'Bank': 1.0,
#   'Lam1': 1.54051,
#   'Lam2': 1.54433,
#   'Zero': 0.0,
#   'Polariz.': 0.7,
#   'Azimuth': 0.0,
#   'I(L2)/I(L1)': 0.5,
#   'U': 2.0,
#   'V': -2.0,
#   'W': 5.0,
#   'X': 0.0,
#   'Y': 0.0,
#   'Z': 0.0,
#   'SH/L': 0.002,
#   'Source': 'CuKa',
#   'pos0': 18.3,
#   'int0': 1892.4064850164634,
#   'sig0': 4.729748136945508,
#   'gam0': 0.0,
#   'pos1': 30.02,
#   'int1': 5144.062853107962,
#   'sig1': 4.607521583209725,
#   'gam1': 0.0,
#   'pos2': 35.48,
#   'int2': 20114.565227110535,
#   'sig2': 4.564864731271141,
#   'gam2': 0.0,
#   'pos3': 37.1,
#   'int3': 1322.5215598485017,
#   'sig3': 4.554077103000759,
#   'gam3': 0.0,
#   'pos4': 43.14,
#   'int4': 4049.395739058275,
#   'sig4': 4.521914776147684,
#   'gam4': 0.0,
#   'pos5': 53.59,
#   'int5': 1033.2327506442566,
#   'sig5': 4.500050537824671,
#   'gam5': 0.0,
#   'pos6': 57.13,
#   'int6': 3356.0439536436775,
#   'sig6': 4.503947251990532,
#   'gam6': 0.0,
#   'pos7': 62.6,
#   'int7': 5244.955731697154,
#   'sig7': 4.523332117225633,
#   'gam7': 0.0,
#   'Pdabc': []},
#  ['Back;0',
#   'Back;1',
#   'Back;2',
#   'Back;3',
#   'Back;4',
#   'Back;5',
#   'int0',
#   'int1',
#   'int2',
#   'int3',
#   'int4',
#   'int5',
#   'int6',
#   'int7'],
#  [])

# %%
# %matplotlib widget
fig, ax = plt.subplots()
ax.plot(hist.getdata("X"), hist.getdata("yobs"), label="data")
ax.plot(hist.getdata("X"), hist.getdata("ycalc"), label="calculated")
ax.plot(hist.getdata("X"), hist.getdata("background"), label="background")
ax.legend()
# Out:
# /tmp/ipykernel_3573696/2423301582.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### We flag the parameters of the peak we want to refine

# %%
hist.set_peakFlags(
    peaklist=None, #apply to all peaks
    area=True, #Area
    pos=True, # x-position
    sig=True, #Gaussian width
    gam=True, #Lorentzian width
)

# %%
hist.refine_peaks()
# Out:
# Number of function calls: 7 Number of observations: 2451 Number of parameters: 38
# fitpeak time =    0.085s,    0.028s/cycle
# Rwp =   13.32%, chi**2 =      3125.25, reduced chi**2 =   1.30
# Background coefficients for chebyschev-1 function
# value:     15.16962   -13.05341     5.61109    -2.24436    -0.05035     0.66375
# esd  :      0.20416     0.34981     0.29990     0.26306     0.22460     0.20289
# Peak coefficients:
#                 pos       esd       int       esd       sig       esd       gam       esd        bins
#  Peak1   :  18.27989   0.00272    5308.5     150.8    41.553     9.819    11.248     1.487     2.6
#  Peak2   :  30.08508   0.00172   21067.6     221.7    17.456     6.117    22.160     0.694     2.5
#  Peak3   :  35.44179   0.00100   73939.4     392.0    36.333     3.970    23.088     0.370     2.5
#  Peak4   :  37.07599   0.00456    4037.8     150.0   117.768    26.310    10.806     2.785     2.5
#  Peak5   :  43.08158   0.00237   17856.8     207.3    37.196    11.221    26.779     0.976     2.5
#  Peak6   :  53.44228   0.00499    7458.0     156.0   -31.157    14.384    38.933     2.328     2.5
#  Peak7   :  56.97647   0.00276   25501.9     263.9    21.538    18.133    40.752     1.218     2.5
#  Peak8   :  62.56894   0.00263   33973.5     318.8   -82.804     8.050    46.341     1.196     2.5
# *** Warning: data binning yields too few data points across peak FWHM for reliable Rietveld refinement ***
# *** recommended is 6-10; you have 2.50 ***
# ({'Back;0': 0.2041566223596146,
#   'Back;1': 0.3498143143522592,
#   'Back;2': 0.299896336398035,
#   'Back;3': 0.2630569799322718,
#   'Back;4': 0.22460286947119656,
#   'Back;5': 0.20289370607402693,
#   'pos0': 0.0027200271986477535,
#   'int0': 150.82238263209157,
#   'sig0': 9.819052512294615,
#   'gam0': 1.4865950406700754,
#   'pos1': 0.0017176860470947987,
#   'int1': 221.68079766061464,
#   'sig1': 6.117377780467845,
#   'gam1': 0.6935449399840982,
#   'pos2': 0.0009987733766175428,
#   'int2': 391.9853450064965,
#   'sig2': 3.9704048205363422,
#   'gam2': 0.36963548808195373,
#   'pos3': 0.004556994481024356,
#   'int3': 150.02153793664857,
#   'sig3': 26.309807353382926,
#   'gam3': 2.7847769713349635,
#   'pos4': 0.0023733678014898375,
#   'int4': 207.2859653632328,
#   'sig4': 11.220505574085559,
#   'gam4': 0.9761865187125768,
#   'pos5': 0.00499400191996,
#   'int5': 156.01448528761313,
#   'sig5': 14.383728008503448,
#   'gam5': 2.327759584561895,
#   'pos6': 0.0027605612804078726,
#   'int6': 263.85088460453443,
#   'sig6': 18.133136907499352,
#   'gam6': 1.2176310100462318,
#   'pos7': 0.002626426173954727,
#   'int7': 318.81498188966447,
#   'sig7': 8.04960928529607,
#   'gam7': 1.195537895103255},
#  (array([ 1.51696154e+01, -1.30534118e+01,  5.61108770e+00, -2.24436391e+00,
#          -5.03521986e-02,  6.63745793e-01,  1.82798936e+01,  5.30854054e+03,
#           4.15527098e+01,  1.12479323e+01,  3.00850793e+01,  2.10675598e+04,
#           1.74556746e+01,  2.21595979e+01,  3.54417909e+01,  7.39393815e+04,
#           3.63328339e+01,  2.30884599e+01,  3.70759925e+01,  4.03779700e+03,
#           1.17767817e+02,  1.08056969e+01,  4.30815763e+01,  1.78567770e+04,
#           3.71959920e+01,  2.67792450e+01,  5.34422753e+01,  7.45800007e+03,
#          -3.11569478e+01,  3.89326742e+01,  5.69764661e+01,  2.55018746e+04,
#           2.15381805e+01,  4.07519513e+01,  6.25689421e+01,  3.39735179e+04,
#          -8.28041440e+01,  4.63414471e+01]),
#   array([[ 3.21809582e-02,  2.47493317e-03,  3.20259714e-02, ...,
#           -2.03762809e+01,  2.98523011e-01, -7.55175454e-02],
#          [ 2.47493317e-03,  9.44815873e-02, -7.20552456e-05, ...,
#           -3.41802376e+01,  5.04636383e-01, -1.27501020e-01],
#          [ 3.20259714e-02, -7.20552456e-05,  6.94407412e-02, ...,
#           -2.53075337e+01,  3.72332730e-01, -9.39499558e-02],
#          ...,
#          [-2.03762809e+01, -3.41802376e+01, -2.53075337e+01, ...,
#            7.84782790e+04, -4.97230847e+02,  1.27067023e+02],
#          [ 2.98523011e-01,  5.04636383e-01,  3.72332730e-01, ...,
#           -4.97230847e+02,  5.00289778e+01, -6.11851841e+00],
#          [-7.55175454e-02, -1.27501020e-01, -9.39499558e-02, ...,
#            1.27067023e+02, -6.11851841e+00,  1.10356704e+00]]),
#   {'fvec': array([-0.67458533, -1.25007972, -0.97483035, ..., -2.00123768,
#            1.03999131, -3.07124686]),
#    'nfev': 7,
#    'njev': 6,
#    'fjac': array([[-1.14101313e+03,  0.00000000e+00,  0.00000000e+00, ...,
#             0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#           [ 8.58541855e-02,  6.62648691e+02,  2.01242151e-06, ...,
#            -0.00000000e+00, -0.00000000e+00, -0.00000000e+00],
#           [ 2.55718263e-02, -1.62734575e-03,  4.79713800e+02, ...,
#            -0.00000000e+00, -0.00000000e+00, -0.00000000e+00],
#           ...,
#           [-7.02735716e-08,  6.08526313e-08,  6.40116899e-07, ...,
#            -1.59325224e-02, -2.46720816e-02, -1.45404463e-02],
#           [-2.22883022e-08,  1.10265637e-09,  2.51942796e-07, ...,
#             4.77815373e-02,  7.32608043e-02,  4.27489448e-02],
#           [ 3.69555413e-06,  2.81093199e-06, -1.81054323e-06, ...,
#            -2.58594449e-03, -4.00070212e-03, -2.35580892e-03]]),
#    'ipvt': array([15, 11, 23, 35,  7, 31, 19, 27,  1,  6,  5,  4, 18,  3,  2, 14, 26,
#           10, 38, 34, 22, 30, 17, 13, 37,  9, 25, 29, 33, 21, 20,  8, 28, 24,
#           12, 32, 36, 16], dtype=int32),
#    'qtf': array([-9.38685396e-03,  2.96636644e-03, -3.64460972e-03,  9.12599713e-03,
#            4.86447487e-02,  3.57095064e-04,  6.29735011e-03,  7.76177998e-03,
#           -1.09075653e-01,  3.47248104e-02,  8.59949948e-02, -1.33223156e-01,
#           -1.10372219e-01,  8.70964236e-03,  5.20739867e-03,  4.42995137e-05,
#           -4.25061690e-02, -2.61167082e-02,  2.81102721e-02, -1.19035332e-02,
#           -6.79617084e-02, -1.12914705e+00,  5.55637418e-01, -5.74465477e-03,
#           -3.52263925e-02,  6.26679195e-02,  1.79750997e-01,  7.42503830e-01,
#           -4.31979711e-02,  2.67884704e-01,  8.30668036e-02,  8.63285639e-03,
#           -3.29719810e-02,  5.14244112e-02, -2.48612760e-02, -1.43464528e-02,
#           -2.09018907e-03,  4.97614389e-02])},
#   'Both actual and predicted relative reductions in the sum of squares\n  are at most 0.001000',
#   1),
#  array([2.04156622e-01, 3.49814314e-01, 2.99896336e-01, 2.63056980e-01,
#         2.24602869e-01, 2.02893706e-01, 2.72002720e-03, 1.50822383e+02,
#         9.81905251e+00, 1.48659504e+00, 1.71768605e-03, 2.21680798e+02,
#         6.11737778e+00, 6.93544940e-01, 9.98773377e-04, 3.91985345e+02,
#         3.97040482e+00, 3.69635488e-01, 4.55699448e-03, 1.50021538e+02,
#         2.63098074e+01, 2.78477697e+00, 2.37336780e-03, 2.07285965e+02,
#         1.12205056e+01, 9.76186519e-01, 4.99400192e-03, 1.56014485e+02,
#         1.43837280e+01, 2.32775958e+00, 2.76056128e-03, 2.63850885e+02,
#         1.81331369e+01, 1.21763101e+00, 2.62642617e-03, 3.18814982e+02,
#         8.04960929e+00, 1.19553790e+00]),
#  {'Rwp': 13.323428596351276, 'GOF': 1.29517356844797},
#  ['Back;0',
#   'Back;1',
#   'Back;2',
#   'Back;3',
#   'Back;4',
#   'Back;5',
#   'pos0',
#   'int0',
#   'sig0',
#   'gam0',
#   'pos1',
#   'int1',
#   'sig1',
#   'gam1',
#   'pos2',
#   'int2',
#   'sig2',
#   'gam2',
#   'pos3',
#   'int3',
#   'sig3',
#   'gam3',
#   'pos4',
#   'int4',
#   'sig4',
#   'gam4',
#   'pos5',
#   'int5',
#   'sig5',
#   'gam5',
#   'pos6',
#   'int6',
#   'sig6',
#   'gam6',
#   'pos7',
#   'int7',
#   'sig7',
#   'gam7'],
#  {'Back;0': 15.16961544273801,
#   'Back;1': -13.053411834165646,
#   'Back;2': 5.611087697372214,
#   'Back;3': -2.244363909001007,
#   'Back;4': -0.05035219855737632,
#   'Back;5': 0.663745793036232,
#   'nDebye': 0,
#   'nPeaks': 0,
#   'Back File': '',
#   'BF mult': 1.0,
#   'Type': 'PXC',
#   'Bank': 1.0,
#   'Lam1': 1.54051,
#   'Lam2': 1.54433,
#   'Zero': 0.0,
#   'Polariz.': 0.7,
#   'Azimuth': 0.0,
#   'I(L2)/I(L1)': 0.5,
#   'U': 2.0,
#   'V': -2.0,
#   'W': 5.0,
#   'X': 0.0,
#   'Y': 0.0,
#   'Z': 0.0,
#   'SH/L': 0.002,
#   'Source': 'CuKa',
#   'pos0': 18.27989361494396,
#   'int0': 5308.540537965673,
#   'sig0': 41.55270980695642,
#   'gam0': 11.247932307092954,
#   'pos1': 30.085079281993025,
#   'int1': 21067.559829870654,
#   'sig1': 17.455674623480533,
#   'gam1': 22.159597921966206,
#   'pos2': 35.441790881854686,
#   'int2': 73939.38146144385,
#   'sig2': 36.33283391026768,
#   'gam2': 23.088459944445873,
#   'pos3': 37.0759925243461,
#   'int3': 4037.7969994098216,
#   'sig3': 117.76781682478516,
#   'gam3': 10.805696933969,
#   'pos4': 43.08157631291804,
#   'int4': 17856.777048711487,
#   'sig4': 37.19599201553757,
#   'gam4': 26.779245019173118,
#   'pos5': 53.44227530256559,
#   'int5': 7458.000073986845,
#   'sig5': -31.15694781604995,
#   'gam5': 38.93267417694272,
#   'pos6': 56.976466116088496,
#   'int6': 25501.874551219636,
#   'sig6': 21.538180499873164,
#   'gam6': 40.751951313018516,
#   'pos7': 62.56894211498492,
#   'int7': 33973.51787199235,
#   'sig7': -82.80414403431524,
#   'gam7': 46.34144705750499,
#   'Pdabc': []},
#  ['Back;0',
#   'Back;1',
#   'Back;2',
#   'Back;3',
#   'Back;4',
#   'Back;5',
#   'pos0',
#   'int0',
#   'sig0',
#   'gam0',
#   'pos1',
#   'int1',
#   'sig1',
#   'gam1',
#   'pos2',
#   'int2',
#   'sig2',
#   'gam2',
#   'pos3',
#   'int3',
#   'sig3',
#   'gam3',
#   'pos4',
#   'int4',
#   'sig4',
#   'gam4',
#   'pos5',
#   'int5',
#   'sig5',
#   'gam5',
#   'pos6',
#   'int6',
#   'sig6',
#   'gam6',
#   'pos7',
#   'int7',
#   'sig7',
#   'gam7'],
#  [])

# %%
# %matplotlib widget
fig, ax = plt.subplots()
ax.plot(hist.getdata("X"), hist.getdata("yobs"), label="data")
ax.plot(hist.getdata("X"), hist.getdata("ycalc"), label="calculated")
ax.plot(hist.getdata("X"), hist.getdata("background"), label="background")
ax.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
