# %% [markdown]
# # GSAS-II: Phases

# %%
# %matplotlib inline
import G2script as G2
import matplotlib.pyplot as plt
# Out:
# setting up GSASIIscriptable from /home/edgar/work/g2home
# Python gitpython module not installed
# GSAS-II binary directory: /home/edgar/work/g2home/bindist

# %% [markdown]
# #### Create a project

# %%
PROJECT_NAME = 'projects/gsas_phase.gpx'
gpx = G2.G2Project(newgpx=PROJECT_NAME)
gpx.save()
# Out:
# gpx file saved as /home/edgar/work/gsasii_tutorials/projects/gsas_phase.gpx

# %% [markdown]
# #### For the moment, the project is emtpy and does not contain any phase

# %%
gpx.phases()
# Out:
# []

# %% [markdown]
# #### We will start by adding one phase to the project using a CIF file

# %%
zno = gpx.add_phase(
    phasefile='cif/ZnO.cif',
    phasename='zno',
    histograms=[],
)
# Out:
# /home/edgar/work/gsasii_tutorials/cif/ZnO.cif read by Reader CIF
# gpx file saved as /home/edgar/work/gsasii_tutorials/projects/gsas_phase.gpx

# %% [markdown]
# #### The cif file contains a complete phase, with cell parameters and atoms

# %% [markdown]
# #### We can retrieve the cell parameters of the phase as a dict

# %%
zno.get_cell()
# Out:
# {'length_a': 3.2495,
#  'length_b': 3.2495,
#  'length_c': 5.2069,
#  'angle_alpha': 90.0,
#  'angle_beta': 90.0,
#  'angle_gamma': 120.0,
#  'volume': 47.61490819420314}

# %% [markdown]
# #### In a phase, we can check the composition

# %%
zno.composition
# Out:
# {'Zn': 2.0, 'O': 2.0}

# %% [markdown]
# #### We can retrieve the atoms of the cell

# %%
zno.atoms()
# Out:
# [<GSASIIscriptable.G2AtomRecord at 0x7fa5ad49d3f0>,
#  <GSASIIscriptable.G2AtomRecord at 0x7fa5ad49d210>]

# %% [markdown]
# #### At this moment, there is not a histogram associated to the phase, so any method related to HAP is useless

# %%
zno.histograms()
# Out:
# []

# %%
# zno.getHAPvalues()

# %% [markdown]
# #### The Phase is an object with tags and information but it does not contain any data points
# In GSAS-II, the data points are stored only in histograms.
#
# If we want to generate diffraction peaks from the phase, we have to simulate its diffractogram.

# %% [markdown]
# #### First, we have to associate the phase to a histogram

# %%
hist_sim = gpx.add_simulated_powder_histogram(
    histname='hist_simulation_zno',
    iparams='cuka.instprm',
    Tmin=0,
    Tmax=100,
    Tstep=0.05,
    phases=[zno],
)
# Out:
# Simulating 2001 points from 0 to 100 degrees 2theta
# Instrument parameters read: /home/edgar/work/gsasii_tutorials/cuka.instprm (G2 fmt) bank 1

# %% [markdown]
# ##### This object is G2PwdrData

# %%
type(hist_sim)
# Out:
# GSASIIscriptable.G2PwdrData

# %% [markdown]
# #### We just created the object, without data, any generation/refinement of data has to be done explicitly

# %%
# %matplotlib widget
fig, ax = plt.subplots()
ax.plot(hist_sim.getdata("X"), hist_sim.getdata("yobs"), label="data")
ax.legend()
pass
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### The refinement is performed at the project level

# %%
gpx.do_refinements()
# Out:
# gpx file saved as /home/edgar/work/gsasii_tutorials/projects/gsas_phase.gpx
#  Hessian Levenberg-Marquardt SVD refinement on 1 variables:
# initial chi^2 11117 with 2001 obs.
# Read from file:/home/edgar/work/gsasii_tutorials/projects/gsas_phase.bak0.gpx
# Save to file  :/home/edgar/work/gsasii_tutorials/projects/gsas_phase.gpx
# GPX file save successful
#  Refinement results are in file: /home/edgar/work/gsasii_tutorials/projects/gsas_phase.lst
#  ***** Refinement successful *****

# %%
# %matplotlib widget
fig, ax = plt.subplots()
ax.plot(hist_sim.getdata("X"), hist_sim.getdata("yobs"), label="data")
ax.legend()
pass
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### The simulated data, without noise, can be retrieved

# %%
tth = hist_sim.getdata('X')
intensity_obs = hist_sim.getdata('Yobs')
intensity_calc = hist_sim.getdata('Ycalc')

# %%
# %matplotlib widget
fig, axes = plt.subplots(ncols=2, figsize=(12,5))
INTS = [intensity_obs, intensity_calc]
LABELS = ['Observed intensity', 'Calculated intensity']
for ind in range(len(INTS)):
    axes[ind].plot(tth, INTS[ind], label=LABELS[ind])
    axes[ind].set_xlabel('2theta(deg)')
    axes[ind].set_ylabel('Intensity')
    axes[ind].legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
