# %% [markdown]
# # GSAS-II: Quantitative Phase Analysis

# %% [markdown]
# ### Import modules

# %%
import G2script as G2
import matplotlib.pyplot as plt
# Out:
# setting up GSASIIscriptable from /users/edgar1993a/work/g2home
# GSAS-II binary directory: /users/edgar1993a/work/g2home/bindist
# 7 values read from config file /users/edgar1993a/work/g2home/config.py

# %% [markdown]
# ### Create the project as object and save it as a .gpx object

# %%
gpx = G2.G2Project(newgpx='gsas_qpa.gpx')
gpx.save()
# Out:
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_qpa.gpx

# %% [markdown]
# ### We add three phases from .cif files into the project

# %%
al2o3 = gpx.add_phase(phasefile='Al2O3.cif', phasename='alo')
zno = gpx.add_phase(phasefile='ZnO.cif', phasename='zno')
caf2 = gpx.add_phase(phasefile='CaF2.cif', phasename='caf')
# Out:
# /home/edgar1993a/work/pyobjcryst/Al2O3.cif read by Reader CIF
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_qpa.gpx
# /home/edgar1993a/work/pyobjcryst/ZnO.cif read by Reader CIF
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_qpa.gpx
# /home/edgar1993a/work/pyobjcryst/CaF2.cif read by Reader CIF
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_qpa.gpx

# %% [markdown]
# ### Add powder data to the project as a histogram

# %% [markdown]
# #### The histogram is created from powder data in a .prn file, instrument parameters from a .instprm file and phases with the instances

# %%
hist = gpx.add_powder_histogram(datafile='cpd-1h.prn', iparams='cuka.instprm')
# Out:
# Warning: File /home/edgar1993a/work/pyobjcryst/cpd-1h.prn has a validation error, continuing
# /home/edgar1993a/work/pyobjcryst/cpd-1h.prn
# Warning: Bruker brml Reader failed to read /home/edgar1993a/work/pyobjcryst/cpd-1h.prn
# Warning: File /home/edgar1993a/work/pyobjcryst/cpd-1h.prn has a validation error, continuing
# Warning: Bruker RAW Reader failed to read /home/edgar1993a/work/pyobjcryst/cpd-1h.prn
# Warning: File /home/edgar1993a/work/pyobjcryst/cpd-1h.prn has a validation error, continuing
# Warning: CIF Reader failed to read /home/edgar1993a/work/pyobjcryst/cpd-1h.prn
# Skipping header line     5.000       158
#
# Skipping header line     5.020       174
#
# Skipping header line     5.040       174
#
# Warning: FullProf .dat Reader failed to read /home/edgar1993a/work/pyobjcryst/cpd-1h.prn
# Warning: File /home/edgar1993a/work/pyobjcryst/cpd-1h.prn has a validation error, continuing
# GSAS powder data scan error: no BANK records
# Warning: GSAS powder data Reader failed to read /home/edgar1993a/work/pyobjcryst/cpd-1h.prn
# /home/edgar1993a/work/pyobjcryst/cpd-1h.prn read by Reader Topas xye or 2th Fit2D chi
# Instrument parameters read: /home/edgar1993a/work/pyobjcryst/cuka.instprm (G2 fmt) bank None
# 1:3: Trying to find one of END, data_heading
# >     5.000       158
# >     ^
# 1:3: Trying to find one of END, data_heading
# >     5.000       158
# >     ^

# %% [markdown]
# #### For the moment, the histogram only contains observed (experimental) data, the calculated intensity is zero

# %%
tth = hist.getdata('X')
intensity_obs = hist.getdata('Yobs')
intensity_calc = hist.getdata('Ycalc')

# %%
fig, axes = plt.subplots(ncols=2, figsize=(12,5))
INTS = [intensity_obs, intensity_calc]
LABELS = ['Observed intensity', 'Calculated intensity']
for ind in range(len(INTS)):
    axes[ind].plot(tth, INTS[ind], label=LABELS[ind])
    axes[ind].set_xlabel('2theta(deg)')
    axes[ind].set_ylabel('Intensity')
    axes[ind].legend()

# %% [markdown]
# #### Link the phases with the histogram

# %%
for phase in [zno, al2o3, caf2]:
    gpx.link_histogram_phase(phase=phase, histogram=hist)

# %% [markdown]
# #### Do the first refinement to simulate powder diffraction from the phases

# %%
gpx.do_refinements()
# Out:
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_qpa.gpx
#  Hessian Levenberg-Marquardt SVD refinement on 1 variables:
# initial chi^2 8.0151e+05 with 7251 obs.
# Cycle 0: 0.17s, Chi**2: 4.1385e+05 for 7251 obs., Lambda: 0,  Delta: 0.484, SVD=0
# Cycle 1: 0.17s, Chi**2: 4.1385e+05 for 7251 obs., Lambda: 0,  Delta: 1.1e-09, SVD=0
# converged
# Maximum shift/esd = 82.409 for all cycles
# Read from file:/home/edgar1993a/work/pyobjcryst/gsas_qpa.bak0.gpx
# Save to file  :/home/edgar1993a/work/pyobjcryst/gsas_qpa.gpx
# GPX file save successful
#  Refinement results are in file: /home/edgar1993a/work/pyobjcryst/gsas_qpa.lst
#  ***** Refinement successful *****

# %%
fig, axes = plt.subplots(ncols=2, figsize=(12,5))
INTS = [hist.getdata('Yobs'), hist.getdata('Ycalc')]
LABELS = ['Observed intensity', 'Calculated intensity']
for ind in range(len(INTS)):
    axes[ind].plot(hist.getdata('X'), INTS[ind], label=LABELS[ind])
    axes[ind].set_xlabel('2theta(deg)')
    axes[ind].set_ylabel('Intensity')
    axes[ind].legend()

# %% [markdown]
# #### To adjust the weight fractions of the components, first we will fit a background function

# %%
plt.plot(hist.getdata('X'), hist.getdata('Background'))
plt.show()

# %%
background_refinement = {
    "Background" : {
        "no. coeffs" : 15,
        "type" : "chebyschev-1",
        "refine" : True,
    }
}

# %%
hist.set_refinements(background_refinement)

# %%
gpx.do_refinements()
# Out:
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_qpa.gpx
#  Hessian Levenberg-Marquardt SVD refinement on 16 variables:
# initial chi^2 4.1385e+05 with 7251 obs.
# Cycle 0: 0.18s, Chi**2: 2.2352e+05 for 7251 obs., Lambda: 0,  Delta: 0.46, SVD=0
# Cycle 1: 0.18s, Chi**2: 2.2352e+05 for 7251 obs., Lambda: 0,  Delta: 7.03e-09, SVD=0
# converged
# Maximum shift/esd = 54.248 for all cycles
# Read from file:/home/edgar1993a/work/pyobjcryst/gsas_qpa.bak0.gpx
# Save to file  :/home/edgar1993a/work/pyobjcryst/gsas_qpa.gpx
# GPX file save successful
#  Refinement results are in file: /home/edgar1993a/work/pyobjcryst/gsas_qpa.lst
#  ***** Refinement successful *****

# %%
fig, axes = plt.subplots(ncols=3, figsize=(16,5))
INTS = [hist.getdata('Background'), hist.getdata('Ycalc'), hist.getdata('Yobs')]
LABELS = ['Background', 'Calculated intensity', 'Observed intensity']
for ind in range(len(INTS)):
    axes[ind].plot(hist.getdata('X'), INTS[ind], label=LABELS[ind])
    axes[ind].set_xlabel('2theta(deg)')
    axes[ind].set_ylabel('Intensity')
    axes[ind].legend()

# %% [markdown]
# #### We are not fitting the weight fractions yet, called Scale

# %%
for ind, phase in enumerate(gpx.phases()):
    scale = phase.data['Histograms']['PWDR cpd-1h.prn']['Scale'][0]
    weight_fraction = gpx.data['Covariance']['data']['depSigDict'][f'{int(ind)}:0:WgtFrac'][0]
    # print(f"The scale factor of {phase.name} is {scale}")
    print(f"The weight fraction of {phase.name} is {weight_fraction:.3f}")
# Out:
# The weight fraction of alo is 0.563
# The weight fraction of zno is 0.150
# The weight fraction of caf is 0.287

# %%
refinement_scale = {"Scale" : True}

# %%
for phase in [zno, al2o3, caf2]:
    phase.set_HAP_refinements(refinement_scale)

# %%
gpx.do_refinements()
# Out:
# gpx file saved as /home/edgar1993a/work/pyobjcryst/gsas_qpa.gpx
#  Hessian Levenberg-Marquardt SVD refinement on 19 variables:
# initial chi^2 2.2352e+05 with 7251 obs.
# Cycle 0: 0.19s, Chi**2: 1.2225e+05 for 7251 obs., Lambda: 0,  Delta: 0.453, SVD=1
# Cycle 1: 0.18s, Chi**2: 1.2224e+05 for 7251 obs., Lambda: 0,  Delta: 6.99e-05, SVD=1
# converged
# Maximum shift/esd = 71.000 for all cycles
# SVD problem(s) likely from:
#   :0:Scale
# Note highly correlated parameters:
#      :0:Back;1 and :0:Back;3 (@81.97%)
#      :0:Back;2 and :0:Back;4 (@82.34%)
# Read from file:/home/edgar1993a/work/pyobjcryst/gsas_qpa.bak0.gpx
# Save to file  :/home/edgar1993a/work/pyobjcryst/gsas_qpa.gpx
# GPX file save successful
#  Refinement results are in file: /home/edgar1993a/work/pyobjcryst/gsas_qpa.lst
#  ***** Refinement successful *****
# Reported from refinement:
# Warning: Soft (SVD) singularity in the Hessian
# SVD problem(s) likely from:
# :0:Scale
# Note highly correlated parameters:
#      :0:Back;1 and :0:Back;3 (@81.97%)
#      :0:Back;2 and :0:Back;4 (@82.34%)

# %%
for ind, phase in enumerate(gpx.phases()):
    scale = phase.data['Histograms']['PWDR cpd-1h.prn']['Scale'][0]
    weight_fraction = gpx.data['Covariance']['data']['depSigDict'][f'{int(ind)}:0:WgtFrac'][0]
    # print(f"The scale factor of {phase.name} is {scale}")
    print(f"The weight fraction of {phase.name} is {weight_fraction:.3f}")
# Out:
# The weight fraction of alo is 0.294
# The weight fraction of zno is 0.309
# The weight fraction of caf is 0.396

# %%
zno.getHAPvalues(histname='PWDR cpd-1h.prn')
# Out:
# {'Histogram': 'PWDR cpd-1h.prn',
#  'Show': False,
#  'Scale': [2.2432777020621253, True],
#  'Pref.Ori.': ['MD', 1.0, False, [0, 0, 1], 0, {}, [], 0.1],
#  'Size': ['isotropic',
#   [1.0, 1.0, 1.0],
#   [False, False, False],
#   [0, 0, 1],
#   [1.0, 1.0, 1.0, 0.0, 0.0, 0.0],
#   [False, False, False, False, False, False]],
#  'Mustrain': ['isotropic',
#   [1000.0, 1000.0, 1.0],
#   [False, False, False],
#   [0, 0, 1],
#   [0.01, 0.01, 0.01],
#   [False, False, False]],
#  'HStrain': [[0.0, 0.0], [False, False]],
#  'Extinction': [0.0, False],
#  'Babinet': {'BabA': [0.0, False], 'BabU': [0.0, False]},
#  'hId': 0,
#  'Use': True,
#  'LeBail': False}

# %%
gpx.get_VaryList()
# Out:
# ['0:0:Scale',
#  '1:0:Scale',
#  '2:0:Scale',
#  ':0:Back;0',
#  ':0:Back;1',
#  ':0:Back;2',
#  ':0:Back;3',
#  ':0:Back;4',
#  ':0:Back;5',
#  ':0:Back;6',
#  ':0:Back;7',
#  ':0:Back;8',
#  ':0:Back;9',
#  ':0:Back;10',
#  ':0:Back;11',
#  ':0:Back;12',
#  ':0:Back;13',
#  ':0:Back;14',
#  ':0:Scale']

# %% [markdown]
# #### First, we will refine the background function

# %%
hist.plot()

# %%
data = hist.data['data'][1]
plt.plot(data[0], data[1], label='Obs')
plt.plot(data[0], data[3], label='Calc')
plt.legend()
plt.show()

# %%
# zno.set_refinements({'Cell' : True})

# %%
limits = {'Limits' : [0,100]}
params = {'Instrument Parameters' : ['U', 'V', 'W', 'X', 'Y', 'Z']}
param_fraction = {"Scale" : True, "Use" : True}
param_cell = {'Cell' : True}
background = {
    "Background" : {
        "no. coeffs" : 15,
        "type" : "chebyschev-1",
        "refine" : True,
    }
}
cell = {"Cell" : True, "LeBail" : False}

# %%
hist.set_refinements(limits)
hist.set_refinements(background)
hist.set_refinements(params)
alo.set_refinements(cell)
zno.set_refinements(cell)
caf.set_refinements(cell)
alo.set_HAP_refinements(param_fraction)
zno.set_HAP_refinements(param_fraction)
caf.set_HAP_refinements(param_fraction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       2 hist.set_refinements(background)
#       3 hist.set_refinements(params)
# ----> 4 alo.set_refinements(cell)
#       5 zno.set_refinements(cell)
#       6 caf.set_refinements(cell)
#
# NameError: name 'alo' is not defined

# %%
# hist.set_refinements(limits)
# hist.set_refinements(params)
# zno.set_HAP_refinements(param_fraction)
# alo.set_HAP_refinements(param_fraction)
# caf.set_HAP_refinements(param_fraction)
# zno.set_refinements(param_cell)

# %%
gpx.refine()

# %%
# ref_bg = {'set' : {'Background' : {'no. coeffs' : 12, 'refine' : True},
#                    'Sample Parameters' : ['Scale', ],
#                   },
#           'histograms' : [hist],
#           'phases' : [zno],
#           'LeBail' : False,
#           'Cell' : True,
#          }

# %%
# gpx.do_refinements(refinements=[ref_bg])

# %%
data = hist.data['data'][1]
plt.plot(data[0], data[1], label='Obs')
plt.plot(data[0], data[3], label='Calc')
plt.xlim([0,100])
plt.ylim([-10,1000])
plt.legend()
plt.show()
